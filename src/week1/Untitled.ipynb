# %%
#from typing_extensions import self
import qiskit
from qiskit_aer import AerSimulator

def create_phi_plus() -> QuantumCircuit:
    qc = QuantumCircuit(2)
    qc.h(0)
    qc.cx(0,1)
    return qc


#backend = Aer.get_backend("aer_simulator")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-2c9fd6fe73be> in <module>
#       1 #from typing_extensions import self
# ----> 2 import qiskit
#       3 from qiskit_aer import AerSimulator
#       4
#       5 def create_phi_plus() -> QuantumCircuit:
#
# C:\ProgramData\Anaconda3\lib\site-packages\qiskit\__init__.py in <module>
#      59
#      60 # The main qiskit operators
# ---> 61 from qiskit.circuit import ClassicalRegister
#      62 from qiskit.circuit import QuantumRegister
#      63 from qiskit.circuit import AncillaRegister
#
# C:\ProgramData\Anaconda3\lib\site-packages\qiskit\circuit\__init__.py in <module>
#     404 from .bit import Bit
#     405 from .register import Register
# --> 406 from . import library
#     407 from .commutation_checker import CommutationChecker
#     408 from .annotated_operation import AnnotatedOperation, ControlModifier, PowerModifier, InverseModifier
#
# C:\ProgramData\Anaconda3\lib\site-packages\qiskit\circuit\library\__init__.py in <module>
#     502
#     503 from .blueprintcircuit import BlueprintCircuit
# --> 504 from .generalized_gates import (
#     505     Diagonal,
#     506     DiagonalGate,
#
# C:\ProgramData\Anaconda3\lib\site-packages\qiskit\circuit\library\generalized_gates\__init__.py in <module>
#      20 from .pauli import PauliGate
#      21 from .rv import RVGate
# ---> 22 from .linear_function import LinearFunction
#      23 from .isometry import Isometry
#      24 from .uc import UCGate
#
# C:\ProgramData\Anaconda3\lib\site-packages\qiskit\circuit\library\generalized_gates\linear_function.py in <module>
#      17 from qiskit.circuit.quantumcircuit import QuantumCircuit, Gate
#      18 from qiskit.circuit.exceptions import CircuitError
# ---> 19 from qiskit.synthesis.linear import check_invertible_binary_matrix
#      20 from qiskit.circuit.library.generalized_gates.permutation import PermutationGate
#      21
#
# C:\ProgramData\Anaconda3\lib\site-packages\qiskit\synthesis\__init__.py in <module>
#      87 """
#      88
# ---> 89 from .evolution import (
#      90     EvolutionSynthesis,
#      91     ProductFormula,
#
# C:\ProgramData\Anaconda3\lib\site-packages\qiskit\synthesis\evolution\__init__.py in <module>
#      15 from .evolution_synthesis import EvolutionSynthesis
#      16 from .matrix_synthesis import MatrixExponential
# ---> 17 from .product_formula import ProductFormula
#      18 from .lie_trotter import LieTrotter
#      19 from .suzuki_trotter import SuzukiTrotter
#
# C:\ProgramData\Anaconda3\lib\site-packages\qiskit\synthesis\evolution\product_formula.py in <module>
#      18 from qiskit.circuit.parameterexpression import ParameterExpression
#      19 from qiskit.circuit.quantumcircuit import QuantumCircuit
# ---> 20 from qiskit.quantum_info import SparsePauliOp, Pauli
#      21
#      22 from .evolution_synthesis import EvolutionSynthesis
#
# C:\ProgramData\Anaconda3\lib\site-packages\qiskit\quantum_info\__init__.py in <module>
#     122
#     123 from __future__ import annotations
# --> 124 from .analysis import hellinger_distance, hellinger_fidelity, Z2Symmetries
#     125 from .operators import (
#     126     Clifford,
#
# C:\ProgramData\Anaconda3\lib\site-packages\qiskit\quantum_info\analysis\__init__.py in <module>
#      15 from .average import average_data
#      16 from .distance import hellinger_fidelity, hellinger_distance
# ---> 17 from .z2_symmetries import Z2Symmetries
#
# C:\ProgramData\Anaconda3\lib\site-packages\qiskit\quantum_info\analysis\z2_symmetries.py in <module>
#      23
#      24 from qiskit.exceptions import QiskitError
# ---> 25 from ..operators import Pauli, SparsePauliOp
#      26
#      27
#
# C:\ProgramData\Anaconda3\lib\site-packages\qiskit\quantum_info\operators\__init__.py in <module>
#      14
#      15 from __future__ import annotations
# ---> 16 from .channel import PTM, Chi, Choi, Kraus, Stinespring, SuperOp
#      17 from .dihedral import CNOTDihedral
#      18 from .measures import average_gate_fidelity, diamond_norm, gate_error, process_fidelity
#
# C:\ProgramData\Anaconda3\lib\site-packages\qiskit\quantum_info\operators\channel\__init__.py in <module>
#      22
#      23 from __future__ import annotations
# ---> 24 from .superop import SuperOp
#      25 from .choi import Choi
#      26 from .kraus import Kraus
#
# C:\ProgramData\Anaconda3\lib\site-packages\qiskit\quantum_info\operators\channel\superop.py in <module>
#      24 from qiskit.circuit.quantumcircuit import QuantumCircuit
#      25 from qiskit.exceptions import QiskitError
# ---> 26 from qiskit.quantum_info.operators.base_operator import BaseOperator
#      27 from qiskit.quantum_info.operators.channel.quantum_channel import QuantumChannel
#      28 from qiskit.quantum_info.operators.channel.transformations import _bipartite_tensor, _to_superop
#
# C:\ProgramData\Anaconda3\lib\site-packages\qiskit\quantum_info\operators\base_operator.py in <module>
#      22 from qiskit.quantum_info.operators.op_shape import OpShape
#      23
# ---> 24 from .mixins import GroupMixin
#      25
#      26
#
# C:\ProgramData\Anaconda3\lib\site-packages\qiskit\quantum_info\operators\mixins\__init__.py in <module>
#      17 from inspect import getdoc
#      18
# ---> 19 from .group import GroupMixin
#      20 from .adjoint import AdjointMixin
#      21 from .linear import LinearMixin
#
# C:\ProgramData\Anaconda3\lib\site-packages\qiskit\quantum_info\operators\mixins\group.py in <module>
#      24     from typing import Self
#      25 else:
# ---> 26     from typing_extensions import Self
#      27
#      28
#
# ImportError: cannot import name 'Self' from 'typing_extensions' (C:\ProgramData\Anaconda3\lib\site-packages\typing_extensions.py)

# %%
import numpy as np

test = np.array([0,1,2,3])
